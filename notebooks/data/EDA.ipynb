# %% [markdown]
# Diamond Price Prediction
# Introduction About the Data :
# The dataset The goal is to predict price of given diamond (Regression Analysis).
#
# There are 10 independent variables (including id):
#
# id : unique identifier of each diamond
# carat : Carat (ct.) refers to the unique unit of weight measurement used exclusively to weigh gemstones and diamonds.
# cut : Quality of Diamond Cut
# color : Color of Diamond
# clarity : Diamond clarity is a measure of the purity and rarity of the stone, graded by the visibility of these characteristics under 10-power magnification.
# depth : The depth of diamond is its height (in millimeters) measured from the culet (bottom tip) to the table (flat, top surface)
# table : A diamond's table is the facet which can be seen when the stone is viewed face up.
# x : Diamond X dimension
# y : Diamond Y dimension
# x : Diamond Z dimension
# Target variable:
#
# price: Price of the given Diamond.
# Dataset Source Link : https://www.kaggle.com/competitions/playground-series-s3e8/data?select=train.csv

# %%
# !pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in e:\house price pro\venv\lib\site-packages (6.29.0)
# Requirement already satisfied: comm>=0.1.1 in e:\house price pro\venv\lib\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in e:\house price pro\venv\lib\site-packages (from ipykernel) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in e:\house price pro\venv\lib\site-packages (from ipykernel) (8.12.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in e:\house price pro\venv\lib\site-packages (from ipykernel) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in e:\house price pro\venv\lib\site-packages (from ipykernel) (5.7.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in e:\house price pro\venv\lib\site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: nest-asyncio in e:\house price pro\venv\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in e:\house price pro\venv\lib\site-packages (from ipykernel) (23.2)
# Requirement already satisfied: psutil in e:\house price pro\venv\lib\site-packages (from ipykernel) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in e:\house price pro\venv\lib\site-packages (from ipykernel) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in e:\house price pro\venv\lib\site-packages (from ipykernel) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in e:\house price pro\venv\lib\site-packages (from ipykernel) (5.14.1)
# Requirement already satisfied: backcall in e:\house price pro\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: decorator in e:\house price pro\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in e:\house price pro\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.1)
# Requirement already satisfied: pickleshare in e:\house price pro\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in e:\house price pro\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in e:\house price pro\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.17.2)
# Requirement already satisfied: stack-data in e:\house price pro\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: typing-extensions in e:\house price pro\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: colorama in e:\house price pro\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: importlib-metadata>=4.8.3 in e:\house price pro\venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel) (7.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\house price pro\venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in e:\house price pro\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.2.0)
# Requirement already satisfied: pywin32>=300 in e:\house price pro\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (306)
# Requirement already satisfied: zipp>=0.5 in e:\house price pro\venv\lib\site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel) (3.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in e:\house price pro\venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: wcwidth in e:\house price pro\venv\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: six>=1.5 in e:\house price pro\venv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in e:\house price pro\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in e:\house price pro\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.4.1)
# Requirement already satisfied: pure-eval in e:\house price pro\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)

# %%
import pandas as pd

# %% [markdown]
# #### DATA INGESTION STEP

# %%
df=pd.read_csv("https://raw.githubusercontent.com/krishnaik06/FSDSRegression/main/notebooks/data/gemstone.csv")
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
df.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %% [markdown]
# ### NO MISSING VALUES IN DATA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %% [markdown]
# ### LETS DROP THE ID COLUMN

# %%
df=df.drop(labels=["id"],axis=1)

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %% [markdown]
# ##
# CHECK FOR DUPLICATED RECORDS

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 193568    False
# 193569    False
# 193570    False
# 193571    False
# 193572    False
# Length: 193573, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## SEGREGATE NUMERICAL AND CATEGORICAL COLUMNS

# %%
numerical_columns=df.columns[df.dtypes!="object"]
categorical_columns=df.columns[df.dtypes=="object"]

# %%
print("Numerical_columns:",numerical_columns)
print("Categorical_columns:",categorical_columns)
# Out:
# Numerical_columns: Index(['carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')
# Categorical_columns: Index(['cut', 'color', 'clarity'], dtype='object')

# %%
#df["categorical_columns"].describe()
df[categorical_columns].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
df["cut"].value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
df["color"].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
df["clarity"].value_counts()
# Out:
# clarity
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
x=1
for i in numerical_columns:
    sns.histplot(data=df,x=i,kde=True)
    print("\n")
    plt.show()

# %% [markdown]
# ## OR

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.Figure(figsize=(10,10))
for i in numerical_columns:
    sns.distplot(df[numerical_columns])
    print("\n")
    plt.show()
# Out:
# C:\Users\Lakshya\AppData\Local\Temp\ipykernel_16376\2122475049.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[numerical_columns])
# C:\Users\Lakshya\AppData\Local\Temp\ipykernel_16376\2122475049.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[numerical_columns])
# C:\Users\Lakshya\AppData\Local\Temp\ipykernel_16376\2122475049.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[numerical_columns])
# C:\Users\Lakshya\AppData\Local\Temp\ipykernel_16376\2122475049.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[numerical_columns])
# C:\Users\Lakshya\AppData\Local\Temp\ipykernel_16376\2122475049.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[numerical_columns])
# C:\Users\Lakshya\AppData\Local\Temp\ipykernel_16376\2122475049.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[numerical_columns])
# C:\Users\Lakshya\AppData\Local\Temp\ipykernel_16376\2122475049.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[numerical_columns])

# %% [markdown]
# ## Assignment Do the same for categorical data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
x=1
for i in categorical_columns:
    sns.histplot(data=df,x=i,kde=True)
    print("\n")
    plt.show()

# %% [markdown]
# ## CORRELATION

# %%
sns.heatmap(df_sample.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 sns.heatmap(df_sample.corr(),annot=True)
#
# File e:\HOUSE PRICE PRO\venv\lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File e:\HOUSE PRICE PRO\venv\lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File e:\HOUSE PRICE PRO\venv\lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File e:\HOUSE PRICE PRO\venv\lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Ideal'

# %%
##Currently we will not execute this
##df.drop(labels=['x','y','z'],axis=1)
# Out:
#         carat        cut color clarity  depth  table  price
# 0        1.52    Premium     F     VS2   62.2   58.0  13619
# 1        2.03  Very Good     J     SI2   62.0   58.0  13387
# 2        0.70      Ideal     G     VS1   61.2   57.0   2772
# 3        0.32      Ideal     G     VS1   61.6   56.0    666
# 4        1.70    Premium     G     VS2   62.6   59.0  14453
# ...       ...        ...   ...     ...    ...    ...    ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0   1130
# 193569   0.70    Premium     G    VVS2   60.3   58.0   2874
# 193570   0.73  Very Good     F     SI1   63.1   57.0   3036
# 193571   0.34  Very Good     D     SI1   62.9   55.0    681
# 193572   0.71       Good     E     SI2   60.8   64.0   2258
#
# [193573 rows x 7 columns]

# %%
df_sample=df.sample(5000)

# %%
df_sample.head()
# Out:
#         carat      cut color clarity  depth  table     x     y     z  price
# 192565   0.50    Ideal     H     VS2   62.0   56.0  5.08  5.11  3.15   1312
# 116799   0.50    Ideal     F     VS2   61.6   57.0  5.10  5.07  3.14   1654
# 175902   1.01  Premium     D     SI1   62.4   58.0  6.36  6.41  3.99   5780
# 101765   0.90  Premium     F     SI1   59.8   60.0  6.24  6.21  3.72   3724
# 10346    0.72    Ideal     E    VVS2   62.3   53.0  5.72  5.76  3.58   3519

# %%
sns.pairplot(df_sample)

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df["cut"].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
cut_map={'Fair':1,'Good':2,'Very Good':3,'Premium':4,'Ideal':5}

# %%
df["color"].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
color_map=color_map = {"D":1 ,"E":2 ,"F":3 , "G":4 ,"H":5 , "I":6, "J":7}

# %%
df["clarity"].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
clarity_map={"I1":1,"SI2":2 ,"SI1":3 ,"VS2":4 , "VS1":5 , "VVS2":6 , "VVS1":7 ,"IF":8}

# %%
df["cut"]=df["cut"].map(cut_map)
df["clarity"]=df["clarity"].replace(clarity_map)
df["color"]=df["color"].map(color_map)

# %%
df.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z  price
# 0   1.52    4      3        4   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03    3      7        2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70    5      4        5   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32    5      4        5   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    4      4        4   62.6   59.0  7.65  7.61  4.77  14453
